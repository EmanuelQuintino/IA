# %% [markdown]
# # Class 03 - Machine Learning

# %%
import pandas as pd

# %%
df_salary = pd.read_csv("./salary_dataset.csv")
df_salary
# Out:
#      horas_estudo_mes  salario
# 0                57.0   6813.0
# 1                48.0   6855.0
# 2                60.0   5801.0
# 3                73.0   7431.0
# 4                46.0   5475.0
# ..                ...      ...
# 495              58.0   6259.0
# 496              34.0   6099.0
# 497              47.0   6170.0
# 498              37.0   5064.0
# 499              29.0   5236.0
#
# [500 rows x 2 columns]

# %% [markdown]
# ## EDA

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   horas_estudo_mes  500 non-null    float64
#  1   salario           500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
df_salary.describe()
# Out:
#        horas_estudo_mes      salario
# count        500.000000   500.000000
# mean          50.060000  6018.930000
# std           14.659406   848.697853
# min            1.000000  3664.000000
# 25%           39.750000  5473.000000
# 50%           50.000000  6013.500000
# 75%           60.000000  6542.000000
# max          100.000000  9348.000000

# %%
# pip install matplotlib
df_salary["horas_estudo_mes"].plot.hist(bins=20, edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_salary.corr()
# Out:
#                   horas_estudo_mes   salario
# horas_estudo_mes          1.000000  0.818576
# salario                   0.818576  1.000000

# %%
df_salary.plot.scatter(x="horas_estudo_mes", y="salario")
# Out:
# <Axes: xlabel='horas_estudo_mes', ylabel='salario'>

# %% [markdown]
# ## Training Data

# %%
x = df_salary[["horas_estudo_mes"]]
x
# Out:
#      horas_estudo_mes
# 0                57.0
# 1                48.0
# 2                60.0
# 3                73.0
# 4                46.0
# ..                ...
# 495              58.0
# 496              34.0
# 497              47.0
# 498              37.0
# 499              29.0
#
# [500 rows x 1 columns]

# %%
y = df_salary[["salario"]]
y
# Out:
#      salario
# 0     6813.0
# 1     6855.0
# 2     5801.0
# 3     7431.0
# 4     5475.0
# ..       ...
# 495   6259.0
# 496   6099.0
# 497   6170.0
# 498   5064.0
# 499   5236.0
#
# [500 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (400, 1)

# %%
x_test.shape
# Out:
# (100, 1)

# %%
y_train.shape
# Out:
# (400, 1)

# %%
y_test.shape
# Out:
# (100, 1)

# %% [markdown]
# ## Predictive Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.5939334693606823

# %%
hours = [[20], [40], [60], [120]]
model.predict(hours)
# Out:
# c:\Users\emanu\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4560.4207798 ],
#        [5524.05783523],
#        [6487.69489066],
#        [9378.60605695]])
